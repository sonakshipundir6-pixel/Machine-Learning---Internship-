# %% [raw]
# ___DESCRIPTIVE STATISTICS:-
# -Data set which is small in nature.
# __ Measure of cental tendency-
# -> Mean - it gives the average of the data.
#     - finding average of a data describes the whole story of the data set.
#     - Mean average can be find only for the numerical data.
# -> Mode - it used only for catagorical data.
#     - The value that is frequently occur is the mode of the data.
# -> Median - first we have to arrange the data in asscending order and the center value will be the median of the data.

# %% [raw]
# __1.MEASURE OF CENTRAL TENDENCY:-
#     -Mean
#     -Mode
#     -Median

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Asus/Downloads/Sport car price.csv")

# %%
df
# Out:
#          Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0         Porsche       911  2022               3        379            331
# 1     Lamborghini   Huracan  2021             5.2        630            443
# 2         Ferrari   488 GTB  2022             3.9        661            561
# 3            Audi        R8  2022             5.2        562            406
# 4         McLaren      720S  2021               4        710            568
# ...           ...       ...   ...             ...        ...            ...
# 1002   Koenigsegg     Jesko  2022               5       1280           1106
# 1003        Lotus     Evija  2021  Electric Motor       1972           1254
# 1004      McLaren     Senna  2021               4        789            590
# 1005       Pagani    Huayra  2021               6        764            738
# 1006        Rimac    Nevera  2021  Electric Motor       1888           1696
#
#      0-60 MPH Time (seconds) Price (in USD)
# ...

# %%
df=df.iloc[0:301,:]

# %%
df
# Out:
#           Car Make   Car Model  Year Engine Size (L) Horsepower  \
# 0          Porsche         911  2022               3        379
# 1      Lamborghini     Huracan  2021             5.2        630
# 2          Ferrari     488 GTB  2022             3.9        661
# 3             Audi          R8  2022             5.2        562
# 4          McLaren        720S  2021               4        710
# ..             ...         ...   ...             ...        ...
# 296        McLaren      Artura  2021               3        671
# 297  Mercedes-Benz     SLS AMG  2021               4        577
# 298         Nissan  370Z Nismo  2021             3.7        350
# 299        Porsche      Taycan  2022        Electric        616
# 300          Tesla     Model S  2022        Electric       1020
#
#     Torque (lb-ft) 0-60 MPH Time (seconds) Price (in USD)
# 0              331                       4        101,200
# 1              443                     2.8        274,390
# ...

# %%
df.dtypes
# Out:
# Car Make                   object
# Car Model                  object
# Year                        int64
# Engine Size (L)            object
# Horsepower                 object
# Torque (lb-ft)             object
# 0-60 MPH Time (seconds)    object
# Price (in USD)             object
# dtype: object

# %%
df.describe()
# Out:
#               Year
# count   301.000000
# mean   2021.046512
# std       3.421183
# min    1965.000000
# 25%    2021.000000
# 50%    2021.000000
# 75%    2022.000000
# max    2022.000000

# %%
df.describe(include="object")
# Out:
#        Car Make Car Model Engine Size (L) Horsepower Torque (lb-ft)  \
# count       301       301             297        301            301
# unique       36       108              26         86             70
# top     Porsche        GT               4        503            590
# freq         28        16              68         14             16
#
#        0-60 MPH Time (seconds) Price (in USD)
# count                      301            301
# unique                      36            187
# top                        3.5        500,000
# freq                        47              8

# %% [raw]
# __2.MEASURE OF DISPERSION:-
#     -range
#     -quartiles
#     -std
#     -variance

# %%
df.describe()
# Out:
#               Year
# count   301.000000
# mean   2021.046512
# std       3.421183
# min    1965.000000
# 25%    2021.000000
# 50%    2021.000000
# 75%    2022.000000
# max    2022.000000

# %%
range_1=df["Year"].max()-df["Year"].min()

# %%
range_1
# Out:
# 57

# %% [raw]
# These are the quartiles.
# 25%	2021.000000
# 50%	2021.000000
# 75%	2022.000000
# max	2022.000000
# these will be use in outliears.

# %% [raw]
# VARIANCE or std - distance of a data point from its mean.
#  std 3.421183 is provided by the measure of dispersion beforehand.
# we dont need to calculate it.
