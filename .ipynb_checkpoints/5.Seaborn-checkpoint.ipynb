# %% [raw]
# SEABORN--
#     it is dedicated for visualization purpose.
#     it is used for complex graphs for complex data set .
#     we dont need to do beautification as the basic ones are already provided.
# __WHEN TO USE SEABORN--
#     Bivariate -> when both the columns are numerical in nature: use JOINPLOT,                    PAIRPLOT.
#               -> when both the columns are catagorical in nature: (we cannot                     perform analysis for this as one column should be numerical)                    use CATPLOT.
#     Univariate -> when one is numerical in nature: use ELISTPLOT.
#                -> when one is catagorical in nature: use CATPLOT.
#
# -We cant create pie chart in seaborn we have to use matplotlib for that.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/Asus/Loan_Default.csv")

# %%
df
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %% [raw]
# UNIVARIATE CATEGORICAL

# %%
#df["Region"].value_counts()
sns.catplot(x="Region",data=df,kind='count')

# %%
help(sns.catplot)
# Out:
# Help on function catplot in module seaborn.categorical:
#
# catplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     row=None,
#     col=None,
#     kind='strip',
#     estimator='mean',
#     errorbar=('ci', 95),
#     n_boot=1000,
#     seed=None,
#     units=None,
#     weights=None,
#     order=None,
#     hue_order=None,
#     row_order=None,
#     col_order=None,
#     col_wrap=None,
#     height=5,
#     aspect=1,
#     log_scale=None,
#     native_scale=False,
#     formatter=None,
#     orient=None,
#     color=None,
#     palette=None,
#     hue_norm=None,
#     legend='auto',
#     legend_out=True,
#     sharex=True,
#     sharey=True,
#     margin_titles=False,
#     facet_kws=None,
#     ci=<deprecated>,
#     **kwargs
# )
#     Figure-level interface for drawing categorical plots onto a FacetGrid.
#
#     This function provides access to several axes-level functions that
# ...

# %% [markdown]
# UNIVARIATE NUMERICAL FEATURE:

# %%
sns.distplot(df["Credit_Score"])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2516\3816228200.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Credit_Score"])
# <Axes: xlabel='Credit_Score', ylabel='Density'>

# %%
sns.distplot(df["Credit_Score"],hist=False,color="red")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_2516\3227522447.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Credit_Score"],hist=False,color="red")
# <Axes: xlabel='Credit_Score', ylabel='Density'>

# %%
sns.histplot(df["Credit_Score"])
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Count'>

# %%
plt.figure(figsize=(15,5))
sns.histplot(df["Credit_Score"])
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Count'>

# %%
df.dtypes
# Out:
# ID                             int64
# year                           int64
# loan_limit                    object
# Gender                        object
# approv_in_adv                 object
# loan_type                     object
# loan_purpose                  object
# Credit_Worthiness             object
# open_credit                   object
# business_or_commercial        object
# loan_amount                    int64
# rate_of_interest             float64
# Interest_rate_spread         float64
# Upfront_charges              float64
# term                         float64
# Neg_ammortization             object
# interest_only                 object
# lump_sum_payment              object
# property_value               float64
# construction_type             object
# occupancy_type                object
# Secured_by                    object
# total_units                   object
# income                       float64
# credit_type                   object
# ...

# %% [markdown]
# BIVARIATE NUMERICAL FEATURES-
# where ever grid is written the size can not be increased.

# %%
sns.jointplot(x="ID",y="income",data=df,kind="scatter")

# %%
sns.jointplot(x="ID",y="income",data=df,kind="scatter",hue="credit_type")

# %%
sns.pairplot(data=df)
# this creates combination of all numerical values.
# hue should always be catagorical data.

# %% [raw]
# BIVARIATE CATAGORICAL FEATURES-
#     it should be combination of numerical and categorical.

# %%
sns.boxplot(x="Gender",y="loan_amount",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='loan_amount'>

# %%
sns.catplot(x="Gender",y="loan_amount",data=df,kind="swarm")

# %%
sns.catplot(x="Gender",y="loan_amount",data=df,kind="violin")
