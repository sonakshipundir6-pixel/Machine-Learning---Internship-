# %% [raw]
# -where mean will be 0 and standard deviation will be one.
# -outliers are extremely large or small values in a data set.

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Asus/Downloads/BEML_lyst1729240526796 (1).csv")

# %%
df
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# ...

# %%
df=df[["Date","Close"]]

# %%
df
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
# to convert a column in index

df=df.set_index(pd.DatetimeIndex(df["Date"]))

# %%
df
# Out:
#                   Date    Close
# Date
# 2010-01-04  2010-01-04  1135.60
# 2010-01-05  2010-01-05  1134.60
# 2010-01-06  2010-01-06  1139.60
# 2010-01-07  2010-01-07  1144.15
# 2010-01-08  2010-01-08  1144.05
# ...                ...      ...
# 2016-12-26  2016-12-26   950.25
# 2016-12-27  2016-12-27   975.70
# 2016-12-28  2016-12-28   974.40
# 2016-12-29  2016-12-29   986.05
# 2016-12-30  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
df=df.drop("Date",axis=1)

# %%
df
# Out:
#               Close
# Date
# 2010-01-04  1135.60
# 2010-01-05  1134.60
# 2010-01-06  1139.60
# 2010-01-07  1144.15
# 2010-01-08  1144.05
# ...             ...
# 2016-12-26   950.25
# 2016-12-27   975.70
# 2016-12-28   974.40
# 2016-12-29   986.05
# 2016-12-30  1000.60
#
# [1739 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(df["Close"])

# %%
# getting the gain of the dataset

df["gain"]=df.pct_change(periods=1)

# %%
df
# Out:
#               Close      gain
# Date
# 2010-01-04  1135.60       NaN
# 2010-01-05  1134.60 -0.000881
# 2010-01-06  1139.60  0.004407
# 2010-01-07  1144.15  0.003993
# 2010-01-08  1144.05 -0.000087
# ...             ...       ...
# 2016-12-26   950.25 -0.021924
# 2016-12-27   975.70  0.026782
# 2016-12-28   974.40 -0.001332
# 2016-12-29   986.05  0.011956
# 2016-12-30  1000.60  0.014756
#
# [1739 rows x 2 columns]

# %%
sns.distplot(df["gain"])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9524\2779892701.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["gain"])
# <Axes: xlabel='gain', ylabel='Density'>

# %%
df["gain"].describe()
# Out:
# count    1738.000000
# mean        0.000271
# std         0.026431
# min        -0.133940
# 25%        -0.013736
# 50%        -0.001541
# 75%         0.011985
# max         0.198329
# Name: gain, dtype: float64

# %% [raw]
# __Continuation of confidence interval.

# %%
from scipy import stats

# %%
df
# Out:
#               Close      gain
# Date
# 2010-01-04  1135.60       NaN
# 2010-01-05  1134.60 -0.000881
# 2010-01-06  1139.60  0.004407
# 2010-01-07  1144.15  0.003993
# 2010-01-08  1144.05 -0.000087
# ...             ...       ...
# 2016-12-26   950.25 -0.021924
# 2016-12-27   975.70  0.026782
# 2016-12-28   974.40 -0.001332
# 2016-12-29   986.05  0.011956
# 2016-12-30  1000.60  0.014756
#
# [1739 rows x 2 columns]

# %%
beml_gain_ci=stats.norm.interval(0.95,loc=df["gain"].mean(),scale=df["gain"].std())

# %%
print(beml_gain_ci)
# Out:
# (np.float64(-0.051532729680601415), np.float64(0.05207422583871588))

# %%
sns.distplot(df["gain"])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9524\2779892701.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["gain"])
# <Axes: xlabel='gain', ylabel='Density'>
