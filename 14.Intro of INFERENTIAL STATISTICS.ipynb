# %% [raw]
# ____INFERENTIAL STATISTICS
#         a. Confidence Interval
#         b. Hypothesis Testing (t-test,z-test, chi2-test)
#         c. Central Limit Theorem
#         d. Regression Analysis (logistic, linear)
# -it is used for huge enteries of data set.
# -Population- the overall data that we have.
# -Sample- it is random in nature.
# -Distribution- how the data is distributed.
#     a. Continuous Value- the values inside the data set is in numerical type and every entery is different from previous.
#         i) Standard Normal Distibution.(Important)
#         ii) Normal distribution.
#         iii) Exponantial Distribution.
#     b. Discrete value- the values are distinct in nature and are exact in nature.
#         i) Poisson distribution.
#         ii) Binomial distribution.

# %% [raw]
# ____CENTRAL LIMIT THEOREM
# -it says draw a sample from the population and if the sample is normally distributed we can say the population is also normally distributed regardless of the standard deviation and dispersion. The mean of the sample will be close to mean of population.
# -Law Of Large Numbers- the mean of the sample will be close to mean of population.
# -It is very useful in finance.
# -

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Asus/Downloads/employee_lyst1729240478122.csv")

# %%
df
# Out:
#       Department                               Department Name  \
# 0            BOA                   Board of Appeals Department
# 1            BOA                   Board of Appeals Department
# 2            BOA                   Board of Appeals Department
# 3            BOE                            Board of Elections
# 4            BOE                            Board of Elections
# ...          ...                                           ...
# 10100        SHF                              Sheriff's Office
# 10101        ZAH  Office of Zoning and Administrative Hearings
# 10102        ZAH  Office of Zoning and Administrative Hearings
# 10103        ZAH  Office of Zoning and Administrative Hearings
# 10104        ZAH  Office of Zoning and Administrative Hearings
#
#                                            Division Gender  Base Salary  \
# 0                         Board of Appeals Division      F     78902.00
# ...

# %%
population=df["Base Salary"]

# %%
population.describe()
# Out:
# count     10105.000000
# mean      78936.020239
# std       30654.491034
# min        4816.280000
# 25%       56138.000000
# 50%       75290.000000
# 75%       95015.960000
# max      303091.000000
# Name: Base Salary, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(population,color="Purple")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8452\2474986889.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population,color="Purple")
# <Axes: xlabel='Base Salary', ylabel='Density'>

# %%
mean=[]

def cal_sample_mean(sample_size,no_of_sample_mean):
    for i in range(no_of_sample_mean):
        sample_base_salary=population.sample(n=sample_size)
        sample_mean=sample_base_salary.mean()
        mean.append(sample_mean)

    return mean

# %%
mean_1=cal_sample_mean(sample_size=3,no_of_sample_mean=500)

# %%
sns.distplot(mean_1,color="purple")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8452\1294944753.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mean_1,color="purple")
# <Axes: ylabel='Density'>
